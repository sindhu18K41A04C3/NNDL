# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
d = pd.read_csv('/content/kc_house_data.csv')
print(d)
x_min = d['sqft_living'].min()
x_max = d['sqft_living'].max()
y_min = d['price'].min()
y_max = d['price'].max()

#normailzation
for i in d:
  if i!= 'date':
    d[i]=(d[i]-d[i].min())/(d[i].max()-d[i].min())
print(d)
x=np.array(d.iloc[:,5:6])
y=np.array(d.iloc[:,2:3])
print(x)


#spliting training and testing data
train_x,test_x = train_test_split(x,test_size =0.1)
train_y,test_y= train_test_split(y,test_size =0.1)
m=1
c=1
eta=0.001
epochs=100
bs=2
nb = len(train_x)//2
for i in range(epochs):
  batch = 0
  t=0
  while batch < nb:
    h = 0
    gm =0
    gc =0
    while h<bs:
      q = train_y[t]-m*train_x[t]-c
      gm += q*train_x[t]
      gc +=  q
      h =h+1
    gdm = -(gm)/bs
    gdc = -(gc)/bs
    deltam = -eta*gdm
    deltac = -eta*gdc
    m = m + deltam
    c = c + deltac
    batch = batch+1
    t=t+2

#printing final model parametres(m and c) values  
print("Final updated model parametres m = ",m,"and c =",c)

# calculating Mean square error,Root mean square error and mean absolute error for training data set
q = 0
q1=0
for i in range(len(train_x)):
  v=m*train_x[i]+c
  z = int(train_y[i])-int(v)
  q += z**2
  q1+=abs(z)

mse_train = q/len(train_x)
mae_train = q1/len(train_x)
print("mean square error for tarining data:",mse_train)
print("Root mean square error for training data:",mse_train**0.5)
print("mean absolute error for trained dataset:",mae_train)


#calculating Mean square error,Root mean square error and mean absolute error for testing data set
w =0
w1=0
for i in range(len(test_x)):
  v=m*train_x[i]+c
  z = int(train_y[i])-int(v)
  w += z**2
  w1 +=abs(z)

mse_test = w/len(test_x)
mae_test = w1/len(test_x)
print("mean square error for test data:",mse_test)
print("Root mean square error for testing data:",mse_test**0.5)
print("mean absolute error for testing data:",mae_test)
# Denormalising the data
for i in range(len(x)):
  x[i] = ((x[i]*(x_max-x_min))+x_min)
  y[i] = ((y[i]*(y_max-y_min))+y_min)
print(y[0])
# Deploying model  
x_value =int(input("Enter value of x:"))
x_value = (x_value-x_min)/(x_max-x_min)
y_value = m*x_value+c
y_value = y_value*(y_max-y_min)+y_min
print("House price based on square feet area is: ",int(y_value))
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]
#              id             date     price  ...      long  sqft_living15  sqft_lot15
# 0      0.720103  20141013T000000  0.019266  ...  0.217608       0.161934    0.005742
# 1      0.647853  20141209T000000  0.060721  ...  0.166113       0.222165    0.008027
# 2      0.568795  20150225T000000  0.013770  ...  0.237542       0.399415    0.008513
# 3      0.251157  20141209T000000  0.069377  ...  0.104651       0.165376    0.004996
# 4      0.197333  20150218T000000  0.057049  ...  0.393688       0.241094    0.007871
# ...         ...              ...       ...  ...       ...            ...         ...
# 21608  0.026467  20140521T000000  0.037377  ...  0.143688       0.194631    0.000986
# 21609  0.666639  20150223T000000  0.042623  ...  0.130399       0.246257    0.007523
# 21610  0.153783  20140623T000000  0.042898  ...  0.182724       0.106866    0.001558
# 21611  0.029327  20150116T000000  0.042623  ...  0.373754       0.173980    0.000731
# 21612  0.153783  20141015T000000  0.032787  ...  0.182724       0.106866    0.000811
#
# [21613 rows x 21 columns]
# [[0.06716981]
#  [0.17207547]
#  [0.03622642]
#  ...
#  [0.05509434]
#  [0.09886792]
#  [0.05509434]]
# Final updated model parametres m =  [0.01832326] and c = [0.05862158]
# mean square error for tarining data: 5.141123849673539e-05
# Root mean square error for training data: 0.007170163073231695
# mean absolute error for trained dataset: 5.141123849673539e-05
# mean square error for test data: 0.0
# Root mean square error for testing data: 0.0
# mean absolute error for testing data: 0.0
# [221900.]
# Enter value of x:1180
# House price based on square feet area is:  531374
