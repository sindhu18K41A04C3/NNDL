# %%
#RMS Prpo (Active powerload dataset)
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
d = pd.read_csv('/content/Active power load dataset.csv')
print(d)
x_min = d['X'].min()
x_max = d['X'].max()
y_min = d['Y'].min()
y_max = d['Y'].max()

#normalisation
d=(d-d.min())/(d.max()-d.min())
print(d)

x=np.array(d.iloc[:,0:1])
y=np.array(d.iloc[:,1:2])

#spliting training and testing data
train_x,test_x = train_test_split(x,test_size =0.1)
train_y,test_y= train_test_split(y,test_size =0.1)
print(len(train_x))
print(len(test_y))
#Considering values for model parametres(m,c),eta and no of iterations (epochs),gama,vm and vc
m=1
c=1
eta=0.1
epochs=500000
gama =0.9
em,ec=0,0
e=10**-8

#calculating gradient desent for model parametres(m and c) 
#step size(deltam and deltac) 
#updating model parametres
for i in range(epochs):
  for j in range(len(train_x)):
    temp= train_y[j]-(m*train_x[j])-c
    gdm = -train_x[j]*temp
    gdc = -temp
    em =(gama*em)+(1-gama)*(gdm*gdm)
    ec =(gama*ec)+(1-gama)*(gdc*gdc)
    deltam = (-eta/((em+e)**0.5))*gdm
    deltac = (-eta/((ec+e)**0.5))*gdc
    m = m + deltam
    c = c + deltac
#printing final model parametres(m and c) values  
print("Final updated model parametres m = ",m,"and c =",c)

# calculating Mean square error,Root mean square error and mean absolute error for training data set
q = 0
q1 =0
for i in range(len(train_x)):
  v=m*train_x[i]+c
  z = train_y[i]-v
  q += z**2
  q1 +=abs(z)

mse_train = q/len(train_x)
mae_train = q1/len(train_x)
print("mean square error for tarined data:",mse_train)
print("Root mean square error for training data:",mse_train**0.5)
print("mean absolute error for trained dataset:",mae_train)

# calculating Mean square error,Root mean square error and mean absolute error for testing data set
w =0
w1=0
for i in range(len(test_x)):
  v=m*test_x[i]+c
  z = test_y[i]-v
  w += z**2
  w1 +=abs(z)

mse_test = w/len(test_x)
mae_test = w1/len(test_x)
print("mean square error for test data:",mse_test)
print("Root mean square error for testing data:",mse_test**0.5)
print("mean absolute error for testing data:",mae_test)


# Deploying model to predict data
x_value = float(input("Enter load at previous hour: "))
x_value = (x_value-x_min)/(x_max-x_min)
y_value = m*x_value+c
y_value = y_value*(y_max-y_min)+y_min
print("Load at particular hour based on load at previous hour is : ",y_value)
# Out:
#              X           Y
# 0   5641.29720  5571.46296
# 1   5571.46296  5970.82752
# 2   5970.82752  6481.49040
# 3   6481.49040  5984.23320
# 4   5984.23320  6267.62304
# ..         ...         ...
# 85  4567.90752  4862.05308
# 86  4862.05308  4269.55320
# 87  4269.55320  4723.63164
# 88  4723.63164  4731.26976
# 89  4731.26976  4355.28720
#
# [90 rows x 2 columns]
#            X         Y
# 0   0.372781  0.354624
# 1   0.354624  0.458458
# 2   0.458458  0.591230
# 3   0.591230  0.461944
# 4   0.461944  0.535625
# ..       ...       ...
# 85  0.093702  0.170179
# 86  0.170179  0.016130
# 87  0.016130  0.134190
# 88  0.134190  0.136176
# 89  0.136176  0.038421
#
# [90 rows x 2 columns]
# 81
# 9
# Final updated model parametres m =  [0.13784931] and c = [0.40072624]
# mean square error for tarined data: [0.04856792]
# Root mean square error for training data: [0.2203813]
# mean absolute error for trained dataset: [0.19285791]
# mean square error for test data: [0.06466358]
# Root mean square error for testing data: [0.25429035]
# mean absolute error for testing data: [0.2080407]
# Enter load at previous hour: 5641.29720
# Load at particular hour based on load at previous hour is :  [5946.42563171]
